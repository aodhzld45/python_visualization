# %%
import pydataset as pd
# df = pd.DataFrame({'name': ['김지훈', '이유진', '김민지'],
#                    'english': [90, 80, 70]
#                    'math': [50, 90, 90]})
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
import pydataset as pdata
import seaborn as sns
import pandas as pd


# pd.data()
# df = pd.data('mtcars')

chartdf = pdata.data('mtcars')
chartdf
# len(chartdf)

sns

# df_csv = pd.read_csv('exam.csv')
# df_csv
# sns.countplot(data=chartdf x = qsec)
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
import pandas as pd

df_exam = pd.read_excel('./excel_exam.xlsx')
# df_exam['nclass']
# type(df_exam)
# len(df_exam)
# # sum(df_exam['english']) / 20
# sum(df_exam['math']) / 20
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
import pandas as pd
df_csv = pd.read_csv('exam.csv')
df_csv
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
import pandas as pd

df_midterm = pd.DataFrame({'english' : [90,87,77,68],
                          'math' : [50, 60, 100, 20],
                          'nclass' : [1, 1, 2, 2]})


df_midterm.to_csv('output_newdata.csv') # 마이프레임 csv 파일로 워킹 디렉토리에 내보내기
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       87    60       1
# 2       77   100       2
# 3       68    20       2

# %%
import pydataset as pdata
import seaborn as sns
import pandas as pd


# pd.data()
# df = pd.data('mtcars')

chartdf = pdata.data('mtcars')

# len(chartdf)


gearAvg = sum(chartdf['gear']) / 32


# sns.countplot(data = chartdf)
sns.countplot(x = 'mpg', hue = 'hp', data = chartdf)

# df_csv = pd.read_csv('exam.csv')
# df_csv
# sns.countplot(data=chartdf x = qsec)
# Out:
# <Axes: xlabel='mpg', ylabel='count'>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


tip_df = sns.load_dataset("tips")
tip_df

# tip_df.to_excel('test_excel01.xlsx', sheet_name='test01')
# tip_df.read_excel('test_excel01.xlsx')




# estimators = [(np.mean, 'Mean'), ## 평균
#               (np.median, 'Median'), ## 중앙값
#               (np.max, 'Max'), ## 최대값
#               (np.min, 'Min') ## 최소값
#              ]
# sns.set_theme(style="whitegrid") ## figure, axes 스타일
# fig, ax = plt.subplots(2, 2)
# fig.set_size_inches((10,10))
# fig.set_facecolor('white')
# for i, e in enumerate(estimators):
#     estimator = e[0]
#     title = e[1]
#     row = i//2
#     col = i%2
#     cur_ax = ax[row, col]
#     sns.barplot(x="day", y="total_bill", data=tip_df, hue='sex', estimator=estimator,
#                 ax=cur_ax, ## 현재 axes에 그려짐
#                 errwidth=0
#                )
#     cur_ax.set_title(title)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
